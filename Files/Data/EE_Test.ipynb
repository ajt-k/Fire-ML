# %%
import ee 
import numpy as np
import geemap

# %%
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %%
ee.Initialize(project="ee-ajttest")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
m = geemap.Map()

countries = ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017")
roi = countries.filter(ee.Filter.eq("country_na","United States"));

m.addLayer(roi, {}, "United States")
m.centerObject(roi, 4)
display(m)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[39.76850680995396, -99.05366228420321], controls=(WidgetControl(options=['position', 'transparent_…

# %% [markdown]
# ### So basically

# %%
# Load an image.
image = ee.Image('LANDSAT/LC08/C02/T1_TOA/LC08_044034_20140318')

# Define the visualization parameters.
image_viz_params = {
    'bands': ['B3', 'B4', 'B5'],
    'min': 0,
    'max': 0.5,
    'gamma': [0.95, 1.1, 1],
}

# Define a map centered on San Francisco Bay.
map_l8 = geemap.Map(center=[37.5010, -122.1899], zoom=10)

# Add the image layer to the map and display it.
map_l8.add_layer(image, image_viz_params, 'false color composite')
display(map_l8)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[37.501, -122.1899], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchD…

# %%
# define ROI
roi = ee.Geometry.Point([-122.4481,37.7599]).buffer(40_000)

# Load an image.


image = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")\
.filterDate('2016-01-01','2017-01-01')

image_clipped = image.clip(roi)


ee.data.setDeadline(600)

# Define the visualization parameters.
image_viz_params = {
    'bands': ["SR_B4", "SR_B3", "SR_B2"],
    'min': 1,
    'max': 35000,
}

composite = ee.Algorithms.Landsat.simpleComposite(**{
    'collection':image_clipped,
    'asFloat': True
})


# Define a map centered on San Francisco Bay.
map_land = geemap.Map(center=[37.5010, -122.1899], zoom=10)

# Add the image layer to the map and display it.
map_land.add_layer(composite, image_viz_params, 'LandSat RGB')
display(map_land)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ...

# %% [markdown]
# # Load 2012 MODIS land cover and select the IGBP classification.
# cover = ee.Image('MODIS/051/MCD12Q1/2012_01_01').select('Land_Cover_Type_1')
#
# # Define a palette for the 18 distinct land cover classes.
# igbp_palette = [
#     'aec3d4',  # water
#     '152106',
#     '225129',
#     '369b47',
#     '30eb5b',
#     '387242',  # forest
#     '6a2325',
#     'c3aa69',
#     'b76031',
#     'd9903d',
#     '91af40',  # shrub, grass
#     '111149',  # wetlands
#     'cdb33b',  # croplands
#     'cc0013',  # urban
#     '33280d',  # crop mosaic
#     'd7cdcc',  # snow and ice
#     'f7e084',  # barren
#     '6f6f6f',  # tundra
# ]
#
# # Define a map centered on the United States.
# map_palette = geemap.Map(center=[40.413, -99.229], zoom=5)
#
# # Add the image layer to the map and display it. Specify the min and max labels
# # and the color palette matching the labels.
# map_palette.add_layer(
#     cover, {'min': 0, 'max': 17, 'palette': igbp_palette}, 'IGBP classes'
# )
# display(map_palette)

# %%
pRate = ee.ImageCollection("JAXA/GPM_L3/GSMaP/v6/operational")\
.filterDate('2023-12-01', '2024-01-01')\
.mosaic()


Map = geemap.Map(center=[40.413, -99.229], zoom=5)

#countries = ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017")
#roi = countries.filter(ee.Filter.eq("country_na","United States"));

#clipped_pRate = pRate.clip(roi)

imgVisual = {
    'bands': "hourlyPrecipRate",
    'min': 0,
    'max':10,
    'palette':
      ['1621a2', 'ffffff', '03ffff', '13ff03', 'efff00', 'ffb103', 'ff2300']
}




Map.add_layer(pRate, imgVisual, 'name')
display(Map)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[40.413, -99.229], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDat…
# ---------------------------------------------------------------------------
# ...

# %%
# A Sentinel-2 surface reflectance image.
img = ee.Image('COPERNICUS/S2_SR/20210109T185751_20210109T185931_T10SEG')
true_color_viz = {
    'bands': ['B4', 'B3', 'B2'],
    'min': 0,
    'max': 2700,
    'gamma': 1.3,
}
display('Sentinel-2 image', img)
m = geemap.Map()
m.set_center(-122.36, 37.47, 10)
m.add_layer(img, true_color_viz, 'Sentinel-2 image')

# Get masks for all image bands each band has an independent mask.
# Valid pixels are value 1, invalid are 0.
multi_band_mask_img = img.mask()
display('Multi-band mask image', multi_band_mask_img)
m.add_layer(multi_band_mask_img, None, 'Multi-band mask image')

# Get the mask for a single image band.
single_band_mask_img = img.select('B1').mask()
display('Single-band mask image', single_band_mask_img)
m.add_layer(single_band_mask_img, None, 'Single-band mask image')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'Sentinel-2 image'
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
# ...

# %%
# Load an image.
image = ee.Image('LANDSAT/LC08/C02/T1/LC08_044034_20140318')

# All metadata.
display('All metadata:', image)

# Get information about the bands as a list.
band_names = image.bandNames()
display('Band names:', band_names)  # ee.List of band names

# Get projection information from band 1.
b1_proj = image.select('B1').projection()
display('Band 1 projection:', b1_proj)  # ee.Projection object

# Get scale (in meters) information from band 1.
b1_scale = image.select('B1').projection().nominalScale()
display('Band 1 scale:', b1_scale)  # ee.Number


# Get a list of all metadata properties.
properties = image.propertyNames()
display('Metadata properties:', properties)  # ee.List of metadata properties

# Get a specific metadata property.
cloudiness = image.get('CLOUD_COVER')
display('CLOUD_COVER:', cloudiness)  # ee.Number

# Get the timestamp.
ee_date = ee.Date(image.get('system:time_start'))
display('Timestamp:', ee_date)  # ee.Date

# Date objects transferred to the client are milliseconds since UNIX epoch;
# convert to human readable date with ee.Date.format().
display('Datetime:', ee_date.format())  # ISO standard date string

image_viz = {
    'bands': ["B4","B3","B2"],
    'min':0,
    'max':3000,
}

map_test = geemap.Map( zoom=5)
map_test.add_layer(image, image_viz, "name")

display(map_test)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 'All metadata:'
# <div><style>:root {
#   --font-color-primary: var(--jp-content-font-color0, rgba(0, 0, 0, 1));
#   --font-color-secondary: var(--jp-content-font-color2, rgba(0, 0, 0, 0.6));
# ...

# %%
image = ee.Image('LANDSAT/LC08/C02/T1/LC08_044034_20140318').select('B8')

canny = ee.Algorithms.CannyEdgeDetector({
 image: image
})


Map1 = geemap.Map()
Map1.setCenter(-122.054, 37.7295, 10);
Map1.addLayer(canny, {}, 'canny')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
# ...
